# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 5: Alzheimer's Image Classification
#
# ---
# ## Problem Statement
#
# You are a data science team that has been tasked by the UK government to develop a diagnostic solution that can improve the prediction rates of dementia and Alzheimer's within UK hospitals. Using a Convolutional Neural Network on brain scan imaging, our group wishes to predict Alzheimer's disease with at least 50% accuracy and a recall of at least 64%. This metric is benchmarked to the average diagnostic performance of hospitals across the UK for patients, and an improvement in detection here can mean better outcomes and care for those within its early stages.
#
# ---

# %%
# connect to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# check for GPU connection
# %tensorflow_version 2.x
import tensorflow as tf
print("Tensorflow version " + tf.__version__)
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Tensorflow version 2.6.0
# Found GPU at: /device:GPU:0

# %%
# imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.applications import MobileNetV3Small

# %% [markdown]
# ## Pretrained Neural Network

# %% [markdown]
# ### Train and Test Data

# %%
# Create Test and Train 
train_datagen = ImageDataGenerator(rescale=1.0/255, validation_split=0.33)

# Data Augmentation referenced from "Deep Learning with Python by Francois Chollet: Chapter 5"
train_datagen_aug = ImageDataGenerator(rescale=1.0/255, 
                                   validation_split=0.33,
                                   rotation_range=30,
                                   width_shift_range=0.3,
                                   height_shift_range=0.3,
                                   shear_range=0.3,
                                   zoom_range=0.2,
                                   horizontal_flip=True,
                                   fill_mode='nearest')

train_dir = '/content/drive/MyDrive/data/train'
img_width = 176
img_height = 208


train_gen = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=64,
    class_mode='categorical',
    subset='training',
    seed=42
)

train_gen_aug = train_datagen_aug.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=64,
    class_mode='categorical',
    subset='training',
    seed=42
)

validation_gen = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=64,
    class_mode='categorical',
    subset='validation',
    seed=42
)
# Out:
# Found 3433 images belonging to 4 classes.
# Found 3433 images belonging to 4 classes.
# Found 1688 images belonging to 4 classes.

# %%
# number of steps per epoch for training
train_steps = train_gen.samples // train_gen.batch_size
val_steps = validation_gen.samples // validation_gen.batch_size
print(train_steps)
print(val_steps)
# Out:
# 53
# 26

# %%
# display classes
train_gen.class_indices
# Out:
# {'MildDemented': 0,
#  'ModerateDemented': 1,
#  'NonDemented': 2,
#  'VeryMildDemented': 3}

# %%
# check data shape
train_gen.image_shape
# Out:
# (208, 176, 3)

# %% [markdown]
# Base line accuracy is 50%

# %% [markdown]
# ### MobileNetV3

# %%
# instantantiate base model
conv_base = MobileNetV3Small(
    input_shape=(img_width, img_height, 3),
    include_top=False,
    weights='imagenet')
conv_base.trainable = False
conv_base.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_small_224_1.0_float_no_top.h5
# 6701056/6698480 [==============================] - 0s 0us/step
# 6709248/6698480 [==============================] - 0s 0us/step
# Model: "MobilenetV3small"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 176, 208, 3) 0
# __________________________________________________________________________________________________
# rescaling (Rescaling)           (None, 176, 208, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# Conv (Conv2D)                   (None, 88, 104, 16)  432         rescaling[0][0]
# __________________________________________________________________________________________________
# Conv/BatchNorm (BatchNormalizat (None, 88, 104, 16)  64          Conv[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 88, 104, 16)  0           Conv/BatchNorm[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 88, 104, 16)  0           tf.__operators__.add[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   (None, 88, 104, 16)  0           re_lu[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 88, 104, 16)  0           Conv/BatchNorm[0][0]
#                                                                  tf.math.multiply[0][0]
# __________________________________________________________________________________________________
# expanded_conv/depthwise/pad (Ze (None, 89, 105, 16)  0           multiply[0][0]
# __________________________________________________________________________________________________
# expanded_conv/depthwise (Depthw (None, 44, 52, 16)   144         expanded_conv/depthwise/pad[0][0]
# __________________________________________________________________________________________________
# expanded_conv/depthwise/BatchNo (None, 44, 52, 16)   64          expanded_conv/depthwise[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 44, 52, 16)   0           expanded_conv/depthwise/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv/squeeze_excite/Av (None, 1, 1, 16)     0           re_lu_1[0][0]
# __________________________________________________________________________________________________
# expanded_conv/squeeze_excite/Co (None, 1, 1, 8)      136         expanded_conv/squeeze_excite/AvgP
# __________________________________________________________________________________________________
# expanded_conv/squeeze_excite/Re (None, 1, 1, 8)      0           expanded_conv/squeeze_excite/Conv
# __________________________________________________________________________________________________
# expanded_conv/squeeze_excite/Co (None, 1, 1, 16)     144         expanded_conv/squeeze_excite/Relu
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (None, 1, 1, 16)     0           expanded_conv/squeeze_excite/Conv
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 1, 1, 16)     0           tf.__operators__.add_1[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_1 (TFOpLambda) (None, 1, 1, 16)     0           re_lu_2[0][0]
# __________________________________________________________________________________________________
# expanded_conv/squeeze_excite/Mu (None, 44, 52, 16)   0           re_lu_1[0][0]
#                                                                  tf.math.multiply_1[0][0]
# __________________________________________________________________________________________________
# expanded_conv/project (Conv2D)  (None, 44, 52, 16)   256         expanded_conv/squeeze_excite/Mul[
# __________________________________________________________________________________________________
# expanded_conv/project/BatchNorm (None, 44, 52, 16)   64          expanded_conv/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1/expand (Conv2D) (None, 44, 52, 72)   1152        expanded_conv/project/BatchNorm[0
# __________________________________________________________________________________________________
# expanded_conv_1/expand/BatchNor (None, 44, 52, 72)   288         expanded_conv_1/expand[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 44, 52, 72)   0           expanded_conv_1/expand/BatchNorm[
# __________________________________________________________________________________________________
# expanded_conv_1/depthwise/pad ( (None, 45, 53, 72)   0           re_lu_3[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1/depthwise (Dept (None, 22, 26, 72)   648         expanded_conv_1/depthwise/pad[0][
# __________________________________________________________________________________________________
# expanded_conv_1/depthwise/Batch (None, 22, 26, 72)   288         expanded_conv_1/depthwise[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 22, 26, 72)   0           expanded_conv_1/depthwise/BatchNo
# __________________________________________________________________________________________________
# expanded_conv_1/project (Conv2D (None, 22, 26, 24)   1728        re_lu_4[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1/project/BatchNo (None, 22, 26, 24)   96          expanded_conv_1/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2/expand (Conv2D) (None, 22, 26, 88)   2112        expanded_conv_1/project/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_2/expand/BatchNor (None, 22, 26, 88)   352         expanded_conv_2/expand[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 22, 26, 88)   0           expanded_conv_2/expand/BatchNorm[
# __________________________________________________________________________________________________
# expanded_conv_2/depthwise (Dept (None, 22, 26, 88)   792         re_lu_5[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2/depthwise/Batch (None, 22, 26, 88)   352         expanded_conv_2/depthwise[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 22, 26, 88)   0           expanded_conv_2/depthwise/BatchNo
# __________________________________________________________________________________________________
# expanded_conv_2/project (Conv2D (None, 22, 26, 24)   2112        re_lu_6[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2/project/BatchNo (None, 22, 26, 24)   96          expanded_conv_2/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2/Add (Add)       (None, 22, 26, 24)   0           expanded_conv_1/project/BatchNorm
#                                                                  expanded_conv_2/project/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_3/expand (Conv2D) (None, 22, 26, 96)   2304        expanded_conv_2/Add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3/expand/BatchNor (None, 22, 26, 96)   384         expanded_conv_3/expand[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_2 (TFOpLam (None, 22, 26, 96)   0           expanded_conv_3/expand/BatchNorm[
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 22, 26, 96)   0           tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_2 (TFOpLambda) (None, 22, 26, 96)   0           re_lu_7[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 22, 26, 96)   0           expanded_conv_3/expand/BatchNorm[
#                                                                  tf.math.multiply_2[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3/depthwise/pad ( (None, 25, 29, 96)   0           multiply_1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3/depthwise (Dept (None, 11, 13, 96)   2400        expanded_conv_3/depthwise/pad[0][
# __________________________________________________________________________________________________
# expanded_conv_3/depthwise/Batch (None, 11, 13, 96)   384         expanded_conv_3/depthwise[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_3 (TFOpLam (None, 11, 13, 96)   0           expanded_conv_3/depthwise/BatchNo
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (None, 11, 13, 96)   0           tf.__operators__.add_3[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_3 (TFOpLambda) (None, 11, 13, 96)   0           re_lu_8[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 11, 13, 96)   0           expanded_conv_3/depthwise/BatchNo
#                                                                  tf.math.multiply_3[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3/squeeze_excite/ (None, 1, 1, 96)     0           multiply_2[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3/squeeze_excite/ (None, 1, 1, 24)     2328        expanded_conv_3/squeeze_excite/Av
# __________________________________________________________________________________________________
# expanded_conv_3/squeeze_excite/ (None, 1, 1, 24)     0           expanded_conv_3/squeeze_excite/Co
# __________________________________________________________________________________________________
# expanded_conv_3/squeeze_excite/ (None, 1, 1, 96)     2400        expanded_conv_3/squeeze_excite/Re
# __________________________________________________________________________________________________
# tf.__operators__.add_4 (TFOpLam (None, 1, 1, 96)     0           expanded_conv_3/squeeze_excite/Co
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 1, 1, 96)     0           tf.__operators__.add_4[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_4 (TFOpLambda) (None, 1, 1, 96)     0           re_lu_9[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3/squeeze_excite/ (None, 11, 13, 96)   0           multiply_2[0][0]
#                                                                  tf.math.multiply_4[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3/project (Conv2D (None, 11, 13, 40)   3840        expanded_conv_3/squeeze_excite/Mu
# __________________________________________________________________________________________________
# expanded_conv_3/project/BatchNo (None, 11, 13, 40)   160         expanded_conv_3/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4/expand (Conv2D) (None, 11, 13, 240)  9600        expanded_conv_3/project/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_4/expand/BatchNor (None, 11, 13, 240)  960         expanded_conv_4/expand[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_5 (TFOpLam (None, 11, 13, 240)  0           expanded_conv_4/expand/BatchNorm[
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 11, 13, 240)  0           tf.__operators__.add_5[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_5 (TFOpLambda) (None, 11, 13, 240)  0           re_lu_10[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 11, 13, 240)  0           expanded_conv_4/expand/BatchNorm[
#                                                                  tf.math.multiply_5[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4/depthwise (Dept (None, 11, 13, 240)  6000        multiply_3[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4/depthwise/Batch (None, 11, 13, 240)  960         expanded_conv_4/depthwise[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_6 (TFOpLam (None, 11, 13, 240)  0           expanded_conv_4/depthwise/BatchNo
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, 11, 13, 240)  0           tf.__operators__.add_6[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_6 (TFOpLambda) (None, 11, 13, 240)  0           re_lu_11[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 11, 13, 240)  0           expanded_conv_4/depthwise/BatchNo
#                                                                  tf.math.multiply_6[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4/squeeze_excite/ (None, 1, 1, 240)    0           multiply_4[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4/squeeze_excite/ (None, 1, 1, 64)     15424       expanded_conv_4/squeeze_excite/Av
# __________________________________________________________________________________________________
# expanded_conv_4/squeeze_excite/ (None, 1, 1, 64)     0           expanded_conv_4/squeeze_excite/Co
# __________________________________________________________________________________________________
# expanded_conv_4/squeeze_excite/ (None, 1, 1, 240)    15600       expanded_conv_4/squeeze_excite/Re
# __________________________________________________________________________________________________
# tf.__operators__.add_7 (TFOpLam (None, 1, 1, 240)    0           expanded_conv_4/squeeze_excite/Co
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (None, 1, 1, 240)    0           tf.__operators__.add_7[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_7 (TFOpLambda) (None, 1, 1, 240)    0           re_lu_12[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4/squeeze_excite/ (None, 11, 13, 240)  0           multiply_4[0][0]
#                                                                  tf.math.multiply_7[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4/project (Conv2D (None, 11, 13, 40)   9600        expanded_conv_4/squeeze_excite/Mu
# __________________________________________________________________________________________________
# expanded_conv_4/project/BatchNo (None, 11, 13, 40)   160         expanded_conv_4/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4/Add (Add)       (None, 11, 13, 40)   0           expanded_conv_3/project/BatchNorm
#                                                                  expanded_conv_4/project/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_5/expand (Conv2D) (None, 11, 13, 240)  9600        expanded_conv_4/Add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5/expand/BatchNor (None, 11, 13, 240)  960         expanded_conv_5/expand[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_8 (TFOpLam (None, 11, 13, 240)  0           expanded_conv_5/expand/BatchNorm[
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (None, 11, 13, 240)  0           tf.__operators__.add_8[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_8 (TFOpLambda) (None, 11, 13, 240)  0           re_lu_13[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 11, 13, 240)  0           expanded_conv_5/expand/BatchNorm[
#                                                                  tf.math.multiply_8[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5/depthwise (Dept (None, 11, 13, 240)  6000        multiply_5[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5/depthwise/Batch (None, 11, 13, 240)  960         expanded_conv_5/depthwise[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_9 (TFOpLam (None, 11, 13, 240)  0           expanded_conv_5/depthwise/BatchNo
# __________________________________________________________________________________________________
# re_lu_14 (ReLU)                 (None, 11, 13, 240)  0           tf.__operators__.add_9[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_9 (TFOpLambda) (None, 11, 13, 240)  0           re_lu_14[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 11, 13, 240)  0           expanded_conv_5/depthwise/BatchNo
#                                                                  tf.math.multiply_9[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5/squeeze_excite/ (None, 1, 1, 240)    0           multiply_6[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5/squeeze_excite/ (None, 1, 1, 64)     15424       expanded_conv_5/squeeze_excite/Av
# __________________________________________________________________________________________________
# expanded_conv_5/squeeze_excite/ (None, 1, 1, 64)     0           expanded_conv_5/squeeze_excite/Co
# __________________________________________________________________________________________________
# expanded_conv_5/squeeze_excite/ (None, 1, 1, 240)    15600       expanded_conv_5/squeeze_excite/Re
# __________________________________________________________________________________________________
# tf.__operators__.add_10 (TFOpLa (None, 1, 1, 240)    0           expanded_conv_5/squeeze_excite/Co
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, 1, 1, 240)    0           tf.__operators__.add_10[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_10 (TFOpLambda (None, 1, 1, 240)    0           re_lu_15[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5/squeeze_excite/ (None, 11, 13, 240)  0           multiply_6[0][0]
#                                                                  tf.math.multiply_10[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5/project (Conv2D (None, 11, 13, 40)   9600        expanded_conv_5/squeeze_excite/Mu
# __________________________________________________________________________________________________
# expanded_conv_5/project/BatchNo (None, 11, 13, 40)   160         expanded_conv_5/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5/Add (Add)       (None, 11, 13, 40)   0           expanded_conv_4/Add[0][0]
#                                                                  expanded_conv_5/project/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_6/expand (Conv2D) (None, 11, 13, 120)  4800        expanded_conv_5/Add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6/expand/BatchNor (None, 11, 13, 120)  480         expanded_conv_6/expand[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_11 (TFOpLa (None, 11, 13, 120)  0           expanded_conv_6/expand/BatchNorm[
# __________________________________________________________________________________________________
# re_lu_16 (ReLU)                 (None, 11, 13, 120)  0           tf.__operators__.add_11[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_11 (TFOpLambda (None, 11, 13, 120)  0           re_lu_16[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 11, 13, 120)  0           expanded_conv_6/expand/BatchNorm[
#                                                                  tf.math.multiply_11[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6/depthwise (Dept (None, 11, 13, 120)  3000        multiply_7[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6/depthwise/Batch (None, 11, 13, 120)  480         expanded_conv_6/depthwise[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_12 (TFOpLa (None, 11, 13, 120)  0           expanded_conv_6/depthwise/BatchNo
# __________________________________________________________________________________________________
# re_lu_17 (ReLU)                 (None, 11, 13, 120)  0           tf.__operators__.add_12[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_12 (TFOpLambda (None, 11, 13, 120)  0           re_lu_17[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 11, 13, 120)  0           expanded_conv_6/depthwise/BatchNo
#                                                                  tf.math.multiply_12[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6/squeeze_excite/ (None, 1, 1, 120)    0           multiply_8[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6/squeeze_excite/ (None, 1, 1, 32)     3872        expanded_conv_6/squeeze_excite/Av
# __________________________________________________________________________________________________
# expanded_conv_6/squeeze_excite/ (None, 1, 1, 32)     0           expanded_conv_6/squeeze_excite/Co
# __________________________________________________________________________________________________
# expanded_conv_6/squeeze_excite/ (None, 1, 1, 120)    3960        expanded_conv_6/squeeze_excite/Re
# __________________________________________________________________________________________________
# tf.__operators__.add_13 (TFOpLa (None, 1, 1, 120)    0           expanded_conv_6/squeeze_excite/Co
# __________________________________________________________________________________________________
# re_lu_18 (ReLU)                 (None, 1, 1, 120)    0           tf.__operators__.add_13[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_13 (TFOpLambda (None, 1, 1, 120)    0           re_lu_18[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6/squeeze_excite/ (None, 11, 13, 120)  0           multiply_8[0][0]
#                                                                  tf.math.multiply_13[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6/project (Conv2D (None, 11, 13, 48)   5760        expanded_conv_6/squeeze_excite/Mu
# __________________________________________________________________________________________________
# expanded_conv_6/project/BatchNo (None, 11, 13, 48)   192         expanded_conv_6/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7/expand (Conv2D) (None, 11, 13, 144)  6912        expanded_conv_6/project/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_7/expand/BatchNor (None, 11, 13, 144)  576         expanded_conv_7/expand[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_14 (TFOpLa (None, 11, 13, 144)  0           expanded_conv_7/expand/BatchNorm[
# __________________________________________________________________________________________________
# re_lu_19 (ReLU)                 (None, 11, 13, 144)  0           tf.__operators__.add_14[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_14 (TFOpLambda (None, 11, 13, 144)  0           re_lu_19[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 11, 13, 144)  0           expanded_conv_7/expand/BatchNorm[
#                                                                  tf.math.multiply_14[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7/depthwise (Dept (None, 11, 13, 144)  3600        multiply_9[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7/depthwise/Batch (None, 11, 13, 144)  576         expanded_conv_7/depthwise[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_15 (TFOpLa (None, 11, 13, 144)  0           expanded_conv_7/depthwise/BatchNo
# __________________________________________________________________________________________________
# re_lu_20 (ReLU)                 (None, 11, 13, 144)  0           tf.__operators__.add_15[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_15 (TFOpLambda (None, 11, 13, 144)  0           re_lu_20[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 11, 13, 144)  0           expanded_conv_7/depthwise/BatchNo
#                                                                  tf.math.multiply_15[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7/squeeze_excite/ (None, 1, 1, 144)    0           multiply_10[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7/squeeze_excite/ (None, 1, 1, 40)     5800        expanded_conv_7/squeeze_excite/Av
# __________________________________________________________________________________________________
# expanded_conv_7/squeeze_excite/ (None, 1, 1, 40)     0           expanded_conv_7/squeeze_excite/Co
# __________________________________________________________________________________________________
# expanded_conv_7/squeeze_excite/ (None, 1, 1, 144)    5904        expanded_conv_7/squeeze_excite/Re
# __________________________________________________________________________________________________
# tf.__operators__.add_16 (TFOpLa (None, 1, 1, 144)    0           expanded_conv_7/squeeze_excite/Co
# __________________________________________________________________________________________________
# re_lu_21 (ReLU)                 (None, 1, 1, 144)    0           tf.__operators__.add_16[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_16 (TFOpLambda (None, 1, 1, 144)    0           re_lu_21[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7/squeeze_excite/ (None, 11, 13, 144)  0           multiply_10[0][0]
#                                                                  tf.math.multiply_16[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7/project (Conv2D (None, 11, 13, 48)   6912        expanded_conv_7/squeeze_excite/Mu
# __________________________________________________________________________________________________
# expanded_conv_7/project/BatchNo (None, 11, 13, 48)   192         expanded_conv_7/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7/Add (Add)       (None, 11, 13, 48)   0           expanded_conv_6/project/BatchNorm
#                                                                  expanded_conv_7/project/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_8/expand (Conv2D) (None, 11, 13, 288)  13824       expanded_conv_7/Add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8/expand/BatchNor (None, 11, 13, 288)  1152        expanded_conv_8/expand[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_17 (TFOpLa (None, 11, 13, 288)  0           expanded_conv_8/expand/BatchNorm[
# __________________________________________________________________________________________________
# re_lu_22 (ReLU)                 (None, 11, 13, 288)  0           tf.__operators__.add_17[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_17 (TFOpLambda (None, 11, 13, 288)  0           re_lu_22[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 11, 13, 288)  0           expanded_conv_8/expand/BatchNorm[
#                                                                  tf.math.multiply_17[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8/depthwise/pad ( (None, 15, 17, 288)  0           multiply_11[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8/depthwise (Dept (None, 6, 7, 288)    7200        expanded_conv_8/depthwise/pad[0][
# __________________________________________________________________________________________________
# expanded_conv_8/depthwise/Batch (None, 6, 7, 288)    1152        expanded_conv_8/depthwise[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_18 (TFOpLa (None, 6, 7, 288)    0           expanded_conv_8/depthwise/BatchNo
# __________________________________________________________________________________________________
# re_lu_23 (ReLU)                 (None, 6, 7, 288)    0           tf.__operators__.add_18[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_18 (TFOpLambda (None, 6, 7, 288)    0           re_lu_23[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 6, 7, 288)    0           expanded_conv_8/depthwise/BatchNo
#                                                                  tf.math.multiply_18[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8/squeeze_excite/ (None, 1, 1, 288)    0           multiply_12[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8/squeeze_excite/ (None, 1, 1, 72)     20808       expanded_conv_8/squeeze_excite/Av
# __________________________________________________________________________________________________
# expanded_conv_8/squeeze_excite/ (None, 1, 1, 72)     0           expanded_conv_8/squeeze_excite/Co
# __________________________________________________________________________________________________
# expanded_conv_8/squeeze_excite/ (None, 1, 1, 288)    21024       expanded_conv_8/squeeze_excite/Re
# __________________________________________________________________________________________________
# tf.__operators__.add_19 (TFOpLa (None, 1, 1, 288)    0           expanded_conv_8/squeeze_excite/Co
# __________________________________________________________________________________________________
# re_lu_24 (ReLU)                 (None, 1, 1, 288)    0           tf.__operators__.add_19[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_19 (TFOpLambda (None, 1, 1, 288)    0           re_lu_24[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8/squeeze_excite/ (None, 6, 7, 288)    0           multiply_12[0][0]
#                                                                  tf.math.multiply_19[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8/project (Conv2D (None, 6, 7, 96)     27648       expanded_conv_8/squeeze_excite/Mu
# __________________________________________________________________________________________________
# expanded_conv_8/project/BatchNo (None, 6, 7, 96)     384         expanded_conv_8/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9/expand (Conv2D) (None, 6, 7, 576)    55296       expanded_conv_8/project/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_9/expand/BatchNor (None, 6, 7, 576)    2304        expanded_conv_9/expand[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_20 (TFOpLa (None, 6, 7, 576)    0           expanded_conv_9/expand/BatchNorm[
# __________________________________________________________________________________________________
# re_lu_25 (ReLU)                 (None, 6, 7, 576)    0           tf.__operators__.add_20[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_20 (TFOpLambda (None, 6, 7, 576)    0           re_lu_25[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 6, 7, 576)    0           expanded_conv_9/expand/BatchNorm[
#                                                                  tf.math.multiply_20[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9/depthwise (Dept (None, 6, 7, 576)    14400       multiply_13[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9/depthwise/Batch (None, 6, 7, 576)    2304        expanded_conv_9/depthwise[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_21 (TFOpLa (None, 6, 7, 576)    0           expanded_conv_9/depthwise/BatchNo
# __________________________________________________________________________________________________
# re_lu_26 (ReLU)                 (None, 6, 7, 576)    0           tf.__operators__.add_21[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_21 (TFOpLambda (None, 6, 7, 576)    0           re_lu_26[0][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, 6, 7, 576)    0           expanded_conv_9/depthwise/BatchNo
#                                                                  tf.math.multiply_21[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9/squeeze_excite/ (None, 1, 1, 576)    0           multiply_14[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9/squeeze_excite/ (None, 1, 1, 144)    83088       expanded_conv_9/squeeze_excite/Av
# __________________________________________________________________________________________________
# expanded_conv_9/squeeze_excite/ (None, 1, 1, 144)    0           expanded_conv_9/squeeze_excite/Co
# __________________________________________________________________________________________________
# expanded_conv_9/squeeze_excite/ (None, 1, 1, 576)    83520       expanded_conv_9/squeeze_excite/Re
# __________________________________________________________________________________________________
# tf.__operators__.add_22 (TFOpLa (None, 1, 1, 576)    0           expanded_conv_9/squeeze_excite/Co
# __________________________________________________________________________________________________
# re_lu_27 (ReLU)                 (None, 1, 1, 576)    0           tf.__operators__.add_22[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_22 (TFOpLambda (None, 1, 1, 576)    0           re_lu_27[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9/squeeze_excite/ (None, 6, 7, 576)    0           multiply_14[0][0]
#                                                                  tf.math.multiply_22[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9/project (Conv2D (None, 6, 7, 96)     55296       expanded_conv_9/squeeze_excite/Mu
# __________________________________________________________________________________________________
# expanded_conv_9/project/BatchNo (None, 6, 7, 96)     384         expanded_conv_9/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9/Add (Add)       (None, 6, 7, 96)     0           expanded_conv_8/project/BatchNorm
#                                                                  expanded_conv_9/project/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_10/expand (Conv2D (None, 6, 7, 576)    55296       expanded_conv_9/Add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10/expand/BatchNo (None, 6, 7, 576)    2304        expanded_conv_10/expand[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_23 (TFOpLa (None, 6, 7, 576)    0           expanded_conv_10/expand/BatchNorm
# __________________________________________________________________________________________________
# re_lu_28 (ReLU)                 (None, 6, 7, 576)    0           tf.__operators__.add_23[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_23 (TFOpLambda (None, 6, 7, 576)    0           re_lu_28[0][0]
# __________________________________________________________________________________________________
# multiply_15 (Multiply)          (None, 6, 7, 576)    0           expanded_conv_10/expand/BatchNorm
#                                                                  tf.math.multiply_23[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10/depthwise (Dep (None, 6, 7, 576)    14400       multiply_15[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10/depthwise/Batc (None, 6, 7, 576)    2304        expanded_conv_10/depthwise[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_24 (TFOpLa (None, 6, 7, 576)    0           expanded_conv_10/depthwise/BatchN
# __________________________________________________________________________________________________
# re_lu_29 (ReLU)                 (None, 6, 7, 576)    0           tf.__operators__.add_24[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_24 (TFOpLambda (None, 6, 7, 576)    0           re_lu_29[0][0]
# __________________________________________________________________________________________________
# multiply_16 (Multiply)          (None, 6, 7, 576)    0           expanded_conv_10/depthwise/BatchN
#                                                                  tf.math.multiply_24[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10/squeeze_excite (None, 1, 1, 576)    0           multiply_16[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10/squeeze_excite (None, 1, 1, 144)    83088       expanded_conv_10/squeeze_excite/A
# __________________________________________________________________________________________________
# expanded_conv_10/squeeze_excite (None, 1, 1, 144)    0           expanded_conv_10/squeeze_excite/C
# __________________________________________________________________________________________________
# expanded_conv_10/squeeze_excite (None, 1, 1, 576)    83520       expanded_conv_10/squeeze_excite/R
# __________________________________________________________________________________________________
# tf.__operators__.add_25 (TFOpLa (None, 1, 1, 576)    0           expanded_conv_10/squeeze_excite/C
# __________________________________________________________________________________________________
# re_lu_30 (ReLU)                 (None, 1, 1, 576)    0           tf.__operators__.add_25[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_25 (TFOpLambda (None, 1, 1, 576)    0           re_lu_30[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10/squeeze_excite (None, 6, 7, 576)    0           multiply_16[0][0]
#                                                                  tf.math.multiply_25[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10/project (Conv2 (None, 6, 7, 96)     55296       expanded_conv_10/squeeze_excite/M
# __________________________________________________________________________________________________
# expanded_conv_10/project/BatchN (None, 6, 7, 96)     384         expanded_conv_10/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10/Add (Add)      (None, 6, 7, 96)     0           expanded_conv_9/Add[0][0]
#                                                                  expanded_conv_10/project/BatchNor
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 6, 7, 576)    55296       expanded_conv_10/Add[0][0]
# __________________________________________________________________________________________________
# Conv_1/BatchNorm (BatchNormaliz (None, 6, 7, 576)    2304        Conv_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_26 (TFOpLa (None, 6, 7, 576)    0           Conv_1/BatchNorm[0][0]
# __________________________________________________________________________________________________
# re_lu_31 (ReLU)                 (None, 6, 7, 576)    0           tf.__operators__.add_26[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_26 (TFOpLambda (None, 6, 7, 576)    0           re_lu_31[0][0]
# __________________________________________________________________________________________________
# multiply_17 (Multiply)          (None, 6, 7, 576)    0           Conv_1/BatchNorm[0][0]
#                                                                  tf.math.multiply_26[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1, 1, 576)    0           multiply_17[0][0]
# __________________________________________________________________________________________________
# Conv_2 (Conv2D)                 (None, 1, 1, 1024)   590848      global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_27 (TFOpLa (None, 1, 1, 1024)   0           Conv_2[0][0]
# __________________________________________________________________________________________________
# re_lu_32 (ReLU)                 (None, 1, 1, 1024)   0           tf.__operators__.add_27[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_27 (TFOpLambda (None, 1, 1, 1024)   0           re_lu_32[0][0]
# __________________________________________________________________________________________________
# multiply_18 (Multiply)          (None, 1, 1, 1024)   0           Conv_2[0][0]
#                                                                  tf.math.multiply_27[0][0]
# ==================================================================================================
# Total params: 1,529,968
# Trainable params: 0
# Non-trainable params: 1,529,968
# __________________________________________________________________________________________________

# %%
# Neural Net Architecture
def create_model():
  model = Sequential()
  model.add(conv_base)
  model.add(Flatten())
  model.add(Dense(256, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(4, activation='softmax'))
  model.compile(loss='categorical_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy', Precision(), Recall()])
  return model

# %%
# create model
model = create_model()

# %%
# fit and train model
with tf.device('/device:GPU:0'):
  history = model.fit(
      train_gen,
      validation_data=validation_gen,
      epochs=60,
      steps_per_epoch=train_steps,
      validation_steps=val_steps
  )
# Out:
# Epoch 1/60
# 53/53 [==============================] - 1538s 29s/step - loss: 1.1037 - accuracy: 0.4693 - precision: 0.4819 - recall: 0.2769 - val_loss: 1.0363 - val_accuracy: 0.5018 - val_precision: 0.5018 - val_recall: 0.5018
# Epoch 2/60
# 53/53 [==============================] - 9s 173ms/step - loss: 1.0577 - accuracy: 0.4859 - precision: 0.5154 - recall: 0.2378 - val_loss: 1.0372 - val_accuracy: 0.5012 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/60
# 53/53 [==============================] - 9s 172ms/step - loss: 1.0548 - accuracy: 0.4960 - precision: 0.4979 - recall: 0.2149 - val_loss: 1.0363 - val_accuracy: 0.4994 - val_precision: 0.4994 - val_recall: 0.4994
# Epoch 4/60
# 53/53 [==============================] - 9s 172ms/step - loss: 1.0526 - accuracy: 0.4883 - precision: 0.4955 - recall: 0.2116 - val_loss: 1.0376 - val_accuracy: 0.5012 - val_precision: 0.9286 - val_recall: 0.0078
# Epoch 5/60
# 53/53 [==============================] - 9s 169ms/step - loss: 1.0488 - accuracy: 0.4999 - precision: 0.5164 - recall: 0.1864 - val_loss: 1.0313 - val_accuracy: 0.5006 - val_precision: 0.8022 - val_recall: 0.0877
# Epoch 6/60
# 53/53 [==============================] - 9s 173ms/step - loss: 1.0481 - accuracy: 0.4999 - precision: 0.4922 - recall: 0.1962 - val_loss: 1.0330 - val_accuracy: 0.5000 - val_precision: 0.7917 - val_recall: 0.0343
# Epoch 7/60
# 53/53 [==============================] - 9s 172ms/step - loss: 1.0448 - accuracy: 0.4993 - precision: 0.5188 - recall: 0.2615 - val_loss: 1.0396 - val_accuracy: 0.4988 - val_precision: 0.4979 - val_recall: 0.4970
# Epoch 8/60
# 53/53 [==============================] - 9s 173ms/step - loss: 1.0392 - accuracy: 0.5007 - precision: 0.5175 - recall: 0.2235 - val_loss: 1.0358 - val_accuracy: 0.5000 - val_precision: 0.4997 - val_recall: 0.4982
# Epoch 9/60
# 53/53 [==============================] - 9s 178ms/step - loss: 1.0447 - accuracy: 0.4984 - precision: 0.5121 - recall: 0.2253 - val_loss: 1.0322 - val_accuracy: 0.5018 - val_precision: 0.7975 - val_recall: 0.1160
# Epoch 10/60
# 53/53 [==============================] - 9s 173ms/step - loss: 1.0459 - accuracy: 0.4996 - precision: 0.5299 - recall: 0.2680 - val_loss: 1.0565 - val_accuracy: 0.5000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/60
# 53/53 [==============================] - 9s 171ms/step - loss: 1.0461 - accuracy: 0.4996 - precision: 0.5278 - recall: 0.1971 - val_loss: 1.0296 - val_accuracy: 0.5030 - val_precision: 0.5181 - val_recall: 0.4982
# Epoch 12/60
# 53/53 [==============================] - 9s 170ms/step - loss: 1.0422 - accuracy: 0.4999 - precision: 0.5337 - recall: 0.2817 - val_loss: 1.0334 - val_accuracy: 0.4988 - val_precision: 0.5175 - val_recall: 0.4892
# Epoch 13/60
# 53/53 [==============================] - 9s 172ms/step - loss: 1.0390 - accuracy: 0.4996 - precision: 0.5287 - recall: 0.2297 - val_loss: 1.0304 - val_accuracy: 0.5006 - val_precision: 0.6994 - val_recall: 0.2614
# Epoch 14/60
# 53/53 [==============================] - 9s 171ms/step - loss: 1.0342 - accuracy: 0.4996 - precision: 0.5261 - recall: 0.2695 - val_loss: 1.0263 - val_accuracy: 0.5024 - val_precision: 0.5309 - val_recall: 0.4748
# Epoch 15/60
# 53/53 [==============================] - 9s 170ms/step - loss: 1.0350 - accuracy: 0.5010 - precision: 0.5475 - recall: 0.2752 - val_loss: 1.0312 - val_accuracy: 0.4982 - val_precision: 0.5540 - val_recall: 0.4285
# Epoch 16/60
# 53/53 [==============================] - 9s 171ms/step - loss: 1.0276 - accuracy: 0.5028 - precision: 0.5385 - recall: 0.2618 - val_loss: 1.0315 - val_accuracy: 0.4988 - val_precision: 0.5298 - val_recall: 0.4706
# Epoch 17/60
# 53/53 [==============================] - 9s 172ms/step - loss: 1.0309 - accuracy: 0.5016 - precision: 0.5608 - recall: 0.2752 - val_loss: 1.0281 - val_accuracy: 0.5006 - val_precision: 0.7844 - val_recall: 0.1575
# Epoch 18/60
# 53/53 [==============================] - 9s 172ms/step - loss: 1.0253 - accuracy: 0.5004 - precision: 0.5507 - recall: 0.2787 - val_loss: 1.0275 - val_accuracy: 0.4994 - val_precision: 0.7913 - val_recall: 0.1094
# Epoch 19/60
# 53/53 [==============================] - 9s 171ms/step - loss: 1.0267 - accuracy: 0.5001 - precision: 0.5582 - recall: 0.2606 - val_loss: 1.0276 - val_accuracy: 0.5024 - val_precision: 0.5064 - val_recall: 0.5000
# Epoch 20/60
# 53/53 [==============================] - 9s 172ms/step - loss: 1.0243 - accuracy: 0.5010 - precision: 0.5540 - recall: 0.2757 - val_loss: 1.0269 - val_accuracy: 0.5024 - val_precision: 0.7548 - val_recall: 0.1905
# Epoch 21/60
# 53/53 [==============================] - 9s 171ms/step - loss: 1.0278 - accuracy: 0.5010 - precision: 0.5604 - recall: 0.2493 - val_loss: 1.0235 - val_accuracy: 0.5018 - val_precision: 0.5543 - val_recall: 0.4327
# Epoch 22/60
# 53/53 [==============================] - 9s 172ms/step - loss: 1.0218 - accuracy: 0.4996 - precision: 0.5655 - recall: 0.2743 - val_loss: 1.0203 - val_accuracy: 0.4982 - val_precision: 0.6166 - val_recall: 0.3798
# Epoch 23/60
# 53/53 [==============================] - 9s 171ms/step - loss: 1.0161 - accuracy: 0.5004 - precision: 0.5676 - recall: 0.2841 - val_loss: 1.0294 - val_accuracy: 0.5012 - val_precision: 0.5262 - val_recall: 0.4826
# Epoch 24/60
# 53/53 [==============================] - 9s 171ms/step - loss: 1.0223 - accuracy: 0.5013 - precision: 0.5631 - recall: 0.2570 - val_loss: 1.0181 - val_accuracy: 0.5006 - val_precision: 0.6357 - val_recall: 0.3660
# Epoch 25/60
# 53/53 [==============================] - 9s 171ms/step - loss: 1.0167 - accuracy: 0.4999 - precision: 0.5594 - recall: 0.2615 - val_loss: 1.0156 - val_accuracy: 0.4994 - val_precision: 0.6440 - val_recall: 0.3534
# Epoch 26/60
# 53/53 [==============================] - 9s 172ms/step - loss: 1.0115 - accuracy: 0.5004 - precision: 0.5669 - recall: 0.2995 - val_loss: 1.0191 - val_accuracy: 0.4988 - val_precision: 0.6960 - val_recall: 0.2614
# Epoch 27/60
# 53/53 [==============================] - 9s 174ms/step - loss: 1.0137 - accuracy: 0.5001 - precision: 0.5846 - recall: 0.2707 - val_loss: 1.0205 - val_accuracy: 0.5006 - val_precision: 0.7196 - val_recall: 0.2314
# Epoch 28/60
# 53/53 [==============================] - 9s 170ms/step - loss: 1.0124 - accuracy: 0.4996 - precision: 0.5742 - recall: 0.2790 - val_loss: 1.0274 - val_accuracy: 0.5030 - val_precision: 0.5401 - val_recall: 0.4651
# Epoch 29/60
# 53/53 [==============================] - 9s 170ms/step - loss: 1.0191 - accuracy: 0.5013 - precision: 0.5745 - recall: 0.2645 - val_loss: 1.0420 - val_accuracy: 0.5012 - val_precision: 0.7945 - val_recall: 0.0349
# Epoch 30/60
# 53/53 [==============================] - 9s 171ms/step - loss: 1.0143 - accuracy: 0.4987 - precision: 0.5918 - recall: 0.2573 - val_loss: 1.0160 - val_accuracy: 0.4976 - val_precision: 0.6136 - val_recall: 0.3798
# Epoch 31/60
# 53/53 [==============================] - 9s 172ms/step - loss: 1.0093 - accuracy: 0.5010 - precision: 0.5790 - recall: 0.2947 - val_loss: 1.0257 - val_accuracy: 0.5000 - val_precision: 0.8058 - val_recall: 0.0998
# Epoch 32/60
# 53/53 [==============================] - 9s 168ms/step - loss: 1.0121 - accuracy: 0.5007 - precision: 0.5924 - recall: 0.2416 - val_loss: 1.0158 - val_accuracy: 0.5000 - val_precision: 0.6333 - val_recall: 0.3654
# Epoch 33/60
# 53/53 [==============================] - 9s 170ms/step - loss: 1.0033 - accuracy: 0.4999 - precision: 0.5902 - recall: 0.2885 - val_loss: 1.0143 - val_accuracy: 0.4994 - val_precision: 0.6671 - val_recall: 0.3263
# Epoch 34/60
# 53/53 [==============================] - 9s 169ms/step - loss: 0.9978 - accuracy: 0.5019 - precision: 0.6052 - recall: 0.3057 - val_loss: 1.0113 - val_accuracy: 0.5012 - val_precision: 0.6929 - val_recall: 0.2806
# Epoch 35/60
# 53/53 [==============================] - 9s 169ms/step - loss: 1.0028 - accuracy: 0.5007 - precision: 0.6115 - recall: 0.2930 - val_loss: 1.0155 - val_accuracy: 0.4994 - val_precision: 0.6842 - val_recall: 0.3047
# Epoch 36/60
# 53/53 [==============================] - 9s 169ms/step - loss: 0.9983 - accuracy: 0.5013 - precision: 0.6029 - recall: 0.2799 - val_loss: 1.0117 - val_accuracy: 0.5210 - val_precision: 0.6544 - val_recall: 0.3413
# Epoch 37/60
# 53/53 [==============================] - 9s 170ms/step - loss: 0.9933 - accuracy: 0.5010 - precision: 0.6184 - recall: 0.2915 - val_loss: 1.0097 - val_accuracy: 0.5000 - val_precision: 0.6182 - val_recall: 0.3804
# Epoch 38/60
# 53/53 [==============================] - 9s 170ms/step - loss: 0.9973 - accuracy: 0.4972 - precision: 0.5895 - recall: 0.2775 - val_loss: 1.0257 - val_accuracy: 0.5012 - val_precision: 0.5494 - val_recall: 0.4381
# Epoch 39/60
# 53/53 [==============================] - 9s 170ms/step - loss: 0.9968 - accuracy: 0.5034 - precision: 0.5971 - recall: 0.2802 - val_loss: 1.0113 - val_accuracy: 0.5000 - val_precision: 0.6801 - val_recall: 0.3041
# Epoch 40/60
# 53/53 [==============================] - 9s 170ms/step - loss: 0.9946 - accuracy: 0.4993 - precision: 0.5896 - recall: 0.2891 - val_loss: 1.0318 - val_accuracy: 0.4976 - val_precision: 0.5818 - val_recall: 0.4081
# Epoch 41/60
# 53/53 [==============================] - 9s 179ms/step - loss: 0.9994 - accuracy: 0.4990 - precision: 0.6118 - recall: 0.2924 - val_loss: 1.0184 - val_accuracy: 0.5156 - val_precision: 0.6336 - val_recall: 0.3648
# Epoch 42/60
# 53/53 [==============================] - 9s 171ms/step - loss: 0.9901 - accuracy: 0.4957 - precision: 0.6116 - recall: 0.2879 - val_loss: 1.0111 - val_accuracy: 0.5006 - val_precision: 0.6917 - val_recall: 0.2819
# Epoch 43/60
# 53/53 [==============================] - 9s 169ms/step - loss: 0.9973 - accuracy: 0.5058 - precision: 0.6080 - recall: 0.2766 - val_loss: 1.0083 - val_accuracy: 0.5186 - val_precision: 0.6734 - val_recall: 0.3221
# Epoch 44/60
# 53/53 [==============================] - 9s 171ms/step - loss: 0.9938 - accuracy: 0.4963 - precision: 0.6041 - recall: 0.2808 - val_loss: 1.0309 - val_accuracy: 0.5000 - val_precision: 0.5731 - val_recall: 0.4195
# Epoch 45/60
# 53/53 [==============================] - 9s 170ms/step - loss: 0.9871 - accuracy: 0.5028 - precision: 0.6087 - recall: 0.2933 - val_loss: 1.0287 - val_accuracy: 0.5583 - val_precision: 0.7329 - val_recall: 0.2127
# Epoch 46/60
# 53/53 [==============================] - 9s 170ms/step - loss: 0.9926 - accuracy: 0.5034 - precision: 0.6177 - recall: 0.2858 - val_loss: 1.0173 - val_accuracy: 0.5355 - val_precision: 0.6762 - val_recall: 0.3113
# Epoch 47/60
# 53/53 [==============================] - 9s 170ms/step - loss: 0.9930 - accuracy: 0.4981 - precision: 0.6041 - recall: 0.2894 - val_loss: 1.0175 - val_accuracy: 0.5270 - val_precision: 0.6867 - val_recall: 0.2819
# Epoch 48/60
# 53/53 [==============================] - 9s 170ms/step - loss: 0.9933 - accuracy: 0.5058 - precision: 0.6107 - recall: 0.2858 - val_loss: 1.0167 - val_accuracy: 0.5445 - val_precision: 0.7398 - val_recall: 0.2188
# Epoch 49/60
# 53/53 [==============================] - 9s 170ms/step - loss: 0.9947 - accuracy: 0.4969 - precision: 0.6037 - recall: 0.2731 - val_loss: 1.0133 - val_accuracy: 0.5072 - val_precision: 0.6586 - val_recall: 0.3281
# Epoch 50/60
# 53/53 [==============================] - 9s 170ms/step - loss: 0.9962 - accuracy: 0.5037 - precision: 0.6030 - recall: 0.2701 - val_loss: 1.0123 - val_accuracy: 0.5030 - val_precision: 0.6478 - val_recall: 0.3516
# Epoch 51/60
# 53/53 [==============================] - 9s 170ms/step - loss: 0.9861 - accuracy: 0.5076 - precision: 0.6199 - recall: 0.2793 - val_loss: 1.0119 - val_accuracy: 0.5204 - val_precision: 0.6285 - val_recall: 0.3690
# Epoch 52/60
# 53/53 [==============================] - 9s 170ms/step - loss: 0.9880 - accuracy: 0.4951 - precision: 0.6147 - recall: 0.2959 - val_loss: 1.0126 - val_accuracy: 0.5276 - val_precision: 0.6501 - val_recall: 0.3462
# Epoch 53/60
# 53/53 [==============================] - 9s 169ms/step - loss: 0.9878 - accuracy: 0.4999 - precision: 0.6151 - recall: 0.2823 - val_loss: 1.0082 - val_accuracy: 0.5361 - val_precision: 0.6752 - val_recall: 0.3185
# Epoch 54/60
# 53/53 [==============================] - 9s 168ms/step - loss: 0.9881 - accuracy: 0.5019 - precision: 0.6069 - recall: 0.2731 - val_loss: 1.0117 - val_accuracy: 0.5475 - val_precision: 0.7073 - val_recall: 0.2512
# Epoch 55/60
# 53/53 [==============================] - 9s 171ms/step - loss: 0.9962 - accuracy: 0.4990 - precision: 0.6101 - recall: 0.2657 - val_loss: 1.0112 - val_accuracy: 0.5078 - val_precision: 0.6432 - val_recall: 0.3522
# Epoch 56/60
# 53/53 [==============================] - 9s 170ms/step - loss: 0.9914 - accuracy: 0.4981 - precision: 0.5999 - recall: 0.2755 - val_loss: 1.0143 - val_accuracy: 0.5270 - val_precision: 0.6279 - val_recall: 0.3762
# Epoch 57/60
# 53/53 [==============================] - 9s 169ms/step - loss: 0.9926 - accuracy: 0.4990 - precision: 0.6018 - recall: 0.2562 - val_loss: 1.0172 - val_accuracy: 0.5276 - val_precision: 0.5926 - val_recall: 0.4038
# Epoch 58/60
# 53/53 [==============================] - 9s 170ms/step - loss: 0.9920 - accuracy: 0.4957 - precision: 0.6186 - recall: 0.2710 - val_loss: 1.0127 - val_accuracy: 0.5415 - val_precision: 0.6395 - val_recall: 0.3540
# Epoch 59/60
# 53/53 [==============================] - 9s 172ms/step - loss: 0.9892 - accuracy: 0.5001 - precision: 0.6190 - recall: 0.2802 - val_loss: 1.0134 - val_accuracy: 0.5072 - val_precision: 0.6117 - val_recall: 0.3882
# Epoch 60/60
# 53/53 [==============================] - 9s 170ms/step - loss: 0.9859 - accuracy: 0.5001 - precision: 0.6189 - recall: 0.2805 - val_loss: 1.0159 - val_accuracy: 0.5222 - val_precision: 0.6305 - val_recall: 0.3702

# %%
# store accuracy, loss, precision, and recall values
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

prec = history.history['precision']
val_prec = history.history['val_precision']

recall = history.history['recall']
val_recall = history.history['val_recall']

epochs_range = range(60)

# %%
# plot training and validation accuracy
plt.figure(figsize=(12, 8))
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend();

# %%
# plot training and validation loss
plt.figure(figsize=(12, 8))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend();

# %%
# plot training and validation precision
plt.figure(figsize=(12, 8))
plt.plot(epochs_range, prec, label='Training Precision')
plt.plot(epochs_range, val_prec, label='Validation Precision')
plt.title('Training and Validation Precision')
plt.legend();

# %%
# plot training and validation recall
plt.figure(figsize=(12, 8))
plt.plot(epochs_range, recall, label='Training Recall')
plt.plot(epochs_range, val_recall, label='Validation Recall')
plt.title('Training and Validation Recall')
plt.legend();

# %% [markdown]
# Based on all the charts, MobileNetV3 model is slightly overfit, but less overfit than our fine tuned model and InceptionV3 model without data augmentation. It is performaning better than our baseline model. After about 45 epochs the model stops improving. The best accuracy is about 56%, the best precision is about 73% and best recall score is about 21%.

# %% [markdown]
# ### MobileNetV3 with Data Augmentation

# %%
# create model
model_aug = create_model()
model_aug.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# MobilenetV3small (Functional (None, 1, 1, 1024)        1529968
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 1,793,396
# Trainable params: 263,428
# Non-trainable params: 1,529,968
# _________________________________________________________________

# %%
# fit and train model
with tf.device('/device:GPU:0'):
  history = model_aug.fit(
      train_gen_aug,
      validation_data=validation_gen,
      epochs=60,
      steps_per_epoch=train_steps,
      validation_steps=val_steps
  )
# Out:
# Epoch 1/60
# 53/53 [==============================] - 35s 604ms/step - loss: 1.0961 - accuracy: 0.4779 - precision_1: 0.4852 - recall_1: 0.2428 - val_loss: 1.0394 - val_accuracy: 0.4994 - val_precision_1: 0.8810 - val_recall_1: 0.0222
# Epoch 2/60
# 53/53 [==============================] - 31s 587ms/step - loss: 1.0587 - accuracy: 0.4960 - precision_1: 0.5047 - recall_1: 0.2057 - val_loss: 1.0353 - val_accuracy: 0.5018 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 3/60
# 53/53 [==============================] - 31s 582ms/step - loss: 1.0577 - accuracy: 0.4990 - precision_1: 0.5037 - recall_1: 0.2250 - val_loss: 1.0335 - val_accuracy: 0.5024 - val_precision_1: 0.5024 - val_recall_1: 0.5024
# Epoch 4/60
# 53/53 [==============================] - 31s 584ms/step - loss: 1.0593 - accuracy: 0.4972 - precision_1: 0.4964 - recall_1: 0.2033 - val_loss: 1.0362 - val_accuracy: 0.4988 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 5/60
# 53/53 [==============================] - 31s 586ms/step - loss: 1.0507 - accuracy: 0.4999 - precision_1: 0.5049 - recall_1: 0.1849 - val_loss: 1.0360 - val_accuracy: 0.5000 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 6/60
# 53/53 [==============================] - 31s 590ms/step - loss: 1.0494 - accuracy: 0.5013 - precision_1: 0.5012 - recall_1: 0.2449 - val_loss: 1.0327 - val_accuracy: 0.4994 - val_precision_1: 0.7590 - val_recall_1: 0.0379
# Epoch 7/60
# 53/53 [==============================] - 31s 586ms/step - loss: 1.0486 - accuracy: 0.5025 - precision_1: 0.4989 - recall_1: 0.1965 - val_loss: 1.0408 - val_accuracy: 0.5018 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 8/60
# 53/53 [==============================] - 31s 589ms/step - loss: 1.0517 - accuracy: 0.4975 - precision_1: 0.5022 - recall_1: 0.2063 - val_loss: 1.0362 - val_accuracy: 0.5006 - val_precision_1: 0.6952 - val_recall_1: 0.2001
# Epoch 9/60
# 53/53 [==============================] - 31s 588ms/step - loss: 1.0477 - accuracy: 0.5016 - precision_1: 0.5024 - recall_1: 0.2155 - val_loss: 1.0388 - val_accuracy: 0.5036 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 10/60
# 53/53 [==============================] - 31s 587ms/step - loss: 1.0478 - accuracy: 0.5004 - precision_1: 0.4988 - recall_1: 0.2392 - val_loss: 1.0341 - val_accuracy: 0.5006 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 11/60
# 53/53 [==============================] - 31s 589ms/step - loss: 1.0454 - accuracy: 0.5001 - precision_1: 0.5155 - recall_1: 0.2027 - val_loss: 1.0384 - val_accuracy: 0.4976 - val_precision_1: 0.4976 - val_recall_1: 0.4976
# Epoch 12/60
# 53/53 [==============================] - 31s 586ms/step - loss: 1.0518 - accuracy: 0.4993 - precision_1: 0.5186 - recall_1: 0.2107 - val_loss: 1.0349 - val_accuracy: 0.4994 - val_precision_1: 0.6436 - val_recall_1: 0.2680
# Epoch 13/60
# 53/53 [==============================] - 31s 589ms/step - loss: 1.0458 - accuracy: 0.5007 - precision_1: 0.5176 - recall_1: 0.2274 - val_loss: 1.0389 - val_accuracy: 0.5006 - val_precision_1: 0.5006 - val_recall_1: 0.5006
# Epoch 14/60
# 53/53 [==============================] - 31s 585ms/step - loss: 1.0493 - accuracy: 0.5001 - precision_1: 0.5017 - recall_1: 0.2176 - val_loss: 1.0311 - val_accuracy: 0.5012 - val_precision_1: 0.5176 - val_recall_1: 0.4850
# Epoch 15/60
# 53/53 [==============================] - 31s 584ms/step - loss: 1.0469 - accuracy: 0.4996 - precision_1: 0.5047 - recall_1: 0.2072 - val_loss: 1.0400 - val_accuracy: 0.5000 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 16/60
# 53/53 [==============================] - 31s 586ms/step - loss: 1.0462 - accuracy: 0.4987 - precision_1: 0.5068 - recall_1: 0.2226 - val_loss: 1.0434 - val_accuracy: 0.4988 - val_precision_1: 0.5055 - val_recall_1: 0.4928
# Epoch 17/60
# 53/53 [==============================] - 31s 586ms/step - loss: 1.0437 - accuracy: 0.4990 - precision_1: 0.5363 - recall_1: 0.1668 - val_loss: 1.0343 - val_accuracy: 0.5006 - val_precision_1: 0.5006 - val_recall_1: 0.5006
# Epoch 18/60
# 53/53 [==============================] - 31s 586ms/step - loss: 1.0430 - accuracy: 0.5001 - precision_1: 0.5162 - recall_1: 0.2597 - val_loss: 1.0309 - val_accuracy: 0.5000 - val_precision_1: 0.5087 - val_recall_1: 0.4898
# Epoch 19/60
# 53/53 [==============================] - 31s 590ms/step - loss: 1.0471 - accuracy: 0.4981 - precision_1: 0.5183 - recall_1: 0.2565 - val_loss: 1.0335 - val_accuracy: 0.5012 - val_precision_1: 0.6636 - val_recall_1: 0.2596
# Epoch 20/60
# 53/53 [==============================] - 31s 590ms/step - loss: 1.0421 - accuracy: 0.5013 - precision_1: 0.5345 - recall_1: 0.2321 - val_loss: 1.0343 - val_accuracy: 0.5018 - val_precision_1: 0.5012 - val_recall_1: 0.5000
# Epoch 21/60
# 53/53 [==============================] - 31s 587ms/step - loss: 1.0444 - accuracy: 0.5016 - precision_1: 0.5098 - recall_1: 0.2627 - val_loss: 1.0346 - val_accuracy: 0.5012 - val_precision_1: 0.7410 - val_recall_1: 0.0619
# Epoch 22/60
# 53/53 [==============================] - 31s 587ms/step - loss: 1.0459 - accuracy: 0.4990 - precision_1: 0.5100 - recall_1: 0.1971 - val_loss: 1.0351 - val_accuracy: 0.4976 - val_precision_1: 0.8000 - val_recall_1: 0.0409
# Epoch 23/60
# 53/53 [==============================] - 31s 591ms/step - loss: 1.0493 - accuracy: 0.5004 - precision_1: 0.5136 - recall_1: 0.2131 - val_loss: 1.0377 - val_accuracy: 0.5000 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 24/60
# 53/53 [==============================] - 31s 589ms/step - loss: 1.0452 - accuracy: 0.5001 - precision_1: 0.5067 - recall_1: 0.2244 - val_loss: 1.0344 - val_accuracy: 0.4988 - val_precision_1: 0.8000 - val_recall_1: 0.0024
# Epoch 25/60
# 53/53 [==============================] - 31s 589ms/step - loss: 1.0452 - accuracy: 0.4999 - precision_1: 0.5114 - recall_1: 0.2131 - val_loss: 1.0357 - val_accuracy: 0.4976 - val_precision_1: 0.7692 - val_recall_1: 0.0300
# Epoch 26/60
# 53/53 [==============================] - 31s 590ms/step - loss: 1.0385 - accuracy: 0.5004 - precision_1: 0.5270 - recall_1: 0.2348 - val_loss: 1.0321 - val_accuracy: 0.5012 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 27/60
# 53/53 [==============================] - 31s 586ms/step - loss: 1.0442 - accuracy: 0.4981 - precision_1: 0.5345 - recall_1: 0.2300 - val_loss: 1.0402 - val_accuracy: 0.4994 - val_precision_1: 0.4994 - val_recall_1: 0.4994
# Epoch 28/60
# 53/53 [==============================] - 31s 590ms/step - loss: 1.0443 - accuracy: 0.4993 - precision_1: 0.5080 - recall_1: 0.1968 - val_loss: 1.0320 - val_accuracy: 0.4988 - val_precision_1: 0.7045 - val_recall_1: 0.1046
# Epoch 29/60
# 53/53 [==============================] - 31s 587ms/step - loss: 1.0460 - accuracy: 0.4984 - precision_1: 0.4975 - recall_1: 0.2051 - val_loss: 1.0340 - val_accuracy: 0.5006 - val_precision_1: 0.8333 - val_recall_1: 0.0060
# Epoch 30/60
# 53/53 [==============================] - 31s 586ms/step - loss: 1.0431 - accuracy: 0.4981 - precision_1: 0.5290 - recall_1: 0.2547 - val_loss: 1.0357 - val_accuracy: 0.5000 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 31/60
# 53/53 [==============================] - 31s 581ms/step - loss: 1.0498 - accuracy: 0.5001 - precision_1: 0.4930 - recall_1: 0.1876 - val_loss: 1.0395 - val_accuracy: 0.5000 - val_precision_1: 0.5000 - val_recall_1: 0.5000
# Epoch 32/60
# 53/53 [==============================] - 31s 581ms/step - loss: 1.0410 - accuracy: 0.4996 - precision_1: 0.5008 - recall_1: 0.1820 - val_loss: 1.0335 - val_accuracy: 0.5000 - val_precision_1: 0.4991 - val_recall_1: 0.4982
# Epoch 33/60
# 53/53 [==============================] - 31s 588ms/step - loss: 1.0498 - accuracy: 0.5001 - precision_1: 0.5120 - recall_1: 0.2289 - val_loss: 1.0322 - val_accuracy: 0.5012 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 34/60
# 53/53 [==============================] - 31s 588ms/step - loss: 1.0399 - accuracy: 0.4996 - precision_1: 0.5224 - recall_1: 0.2247 - val_loss: 1.0333 - val_accuracy: 0.5018 - val_precision_1: 0.8333 - val_recall_1: 0.0180
# Epoch 35/60
# 53/53 [==============================] - 31s 587ms/step - loss: 1.0411 - accuracy: 0.5004 - precision_1: 0.5349 - recall_1: 0.2550 - val_loss: 1.0368 - val_accuracy: 0.4994 - val_precision_1: 0.4991 - val_recall_1: 0.4988
# Epoch 36/60
# 53/53 [==============================] - 31s 588ms/step - loss: 1.0472 - accuracy: 0.4984 - precision_1: 0.5161 - recall_1: 0.2099 - val_loss: 1.0355 - val_accuracy: 0.4988 - val_precision_1: 0.5000 - val_recall_1: 6.0096e-04
# Epoch 37/60
# 53/53 [==============================] - 31s 590ms/step - loss: 1.0394 - accuracy: 0.5007 - precision_1: 0.5360 - recall_1: 0.2737 - val_loss: 1.0340 - val_accuracy: 0.4994 - val_precision_1: 0.4988 - val_recall_1: 0.4982
# Epoch 38/60
# 53/53 [==============================] - 31s 590ms/step - loss: 1.0400 - accuracy: 0.4996 - precision_1: 0.5234 - recall_1: 0.2161 - val_loss: 1.0317 - val_accuracy: 0.5006 - val_precision_1: 0.5006 - val_recall_1: 0.4970
# Epoch 39/60
# 53/53 [==============================] - 31s 585ms/step - loss: 1.0443 - accuracy: 0.4993 - precision_1: 0.5108 - recall_1: 0.2467 - val_loss: 1.0337 - val_accuracy: 0.4982 - val_precision_1: 0.5903 - val_recall_1: 0.3672
# Epoch 40/60
# 53/53 [==============================] - 31s 587ms/step - loss: 1.0442 - accuracy: 0.5019 - precision_1: 0.5044 - recall_1: 0.2033 - val_loss: 1.0358 - val_accuracy: 0.4988 - val_precision_1: 0.4985 - val_recall_1: 0.4952
# Epoch 41/60
# 53/53 [==============================] - 31s 587ms/step - loss: 1.0382 - accuracy: 0.5013 - precision_1: 0.5056 - recall_1: 0.2431 - val_loss: 1.0341 - val_accuracy: 0.4976 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 42/60
# 53/53 [==============================] - 31s 584ms/step - loss: 1.0384 - accuracy: 0.4987 - precision_1: 0.5287 - recall_1: 0.1998 - val_loss: 1.0318 - val_accuracy: 0.5018 - val_precision_1: 0.5951 - val_recall_1: 0.3684
# Epoch 43/60
# 53/53 [==============================] - 31s 585ms/step - loss: 1.0407 - accuracy: 0.5007 - precision_1: 0.5208 - recall_1: 0.2342 - val_loss: 1.0332 - val_accuracy: 0.4982 - val_precision_1: 0.8049 - val_recall_1: 0.0198
# Epoch 44/60
# 53/53 [==============================] - 31s 581ms/step - loss: 1.0429 - accuracy: 0.4975 - precision_1: 0.5286 - recall_1: 0.2280 - val_loss: 1.0414 - val_accuracy: 0.4982 - val_precision_1: 0.4982 - val_recall_1: 0.4982
# Epoch 45/60
# 53/53 [==============================] - 31s 585ms/step - loss: 1.0439 - accuracy: 0.4990 - precision_1: 0.5241 - recall_1: 0.2102 - val_loss: 1.0332 - val_accuracy: 0.4994 - val_precision_1: 0.6750 - val_recall_1: 0.2422
# Epoch 46/60
# 53/53 [==============================] - 31s 586ms/step - loss: 1.0410 - accuracy: 0.4990 - precision_1: 0.5141 - recall_1: 0.2600 - val_loss: 1.0327 - val_accuracy: 0.5000 - val_precision_1: 0.7170 - val_recall_1: 0.1340
# Epoch 47/60
# 53/53 [==============================] - 31s 586ms/step - loss: 1.0395 - accuracy: 0.5007 - precision_1: 0.5064 - recall_1: 0.1986 - val_loss: 1.0321 - val_accuracy: 0.5000 - val_precision_1: 0.8333 - val_recall_1: 0.0120
# Epoch 48/60
# 53/53 [==============================] - 31s 591ms/step - loss: 1.0382 - accuracy: 0.5010 - precision_1: 0.5179 - recall_1: 0.2015 - val_loss: 1.0411 - val_accuracy: 0.4994 - val_precision_1: 0.4994 - val_recall_1: 0.4994
# Epoch 49/60
# 53/53 [==============================] - 31s 595ms/step - loss: 1.0413 - accuracy: 0.4984 - precision_1: 0.5391 - recall_1: 0.2351 - val_loss: 1.0300 - val_accuracy: 0.4994 - val_precision_1: 0.6077 - val_recall_1: 0.3239
# Epoch 50/60
# 53/53 [==============================] - 31s 588ms/step - loss: 1.0376 - accuracy: 0.4993 - precision_1: 0.5271 - recall_1: 0.2336 - val_loss: 1.0324 - val_accuracy: 0.5012 - val_precision_1: 0.5084 - val_recall_1: 0.4934
# Epoch 51/60
# 53/53 [==============================] - 31s 587ms/step - loss: 1.0430 - accuracy: 0.4996 - precision_1: 0.5303 - recall_1: 0.2416 - val_loss: 1.0312 - val_accuracy: 0.5000 - val_precision_1: 0.5803 - val_recall_1: 0.3780
# Epoch 52/60
# 53/53 [==============================] - 31s 583ms/step - loss: 1.0412 - accuracy: 0.4984 - precision_1: 0.5140 - recall_1: 0.2018 - val_loss: 1.0320 - val_accuracy: 0.5000 - val_precision_1: 0.8000 - val_recall_1: 0.0024
# Epoch 53/60
# 53/53 [==============================] - 31s 586ms/step - loss: 1.0368 - accuracy: 0.5001 - precision_1: 0.5305 - recall_1: 0.2556 - val_loss: 1.0303 - val_accuracy: 0.4994 - val_precision_1: 0.7032 - val_recall_1: 0.1851
# Epoch 54/60
# 53/53 [==============================] - 31s 586ms/step - loss: 1.0334 - accuracy: 0.5004 - precision_1: 0.5322 - recall_1: 0.2401 - val_loss: 1.0335 - val_accuracy: 0.5000 - val_precision_1: 0.4997 - val_recall_1: 0.4976
# Epoch 55/60
# 53/53 [==============================] - 31s 584ms/step - loss: 1.0399 - accuracy: 0.4981 - precision_1: 0.5328 - recall_1: 0.2553 - val_loss: 1.0352 - val_accuracy: 0.4988 - val_precision_1: 0.4982 - val_recall_1: 0.4976
# Epoch 56/60
# 53/53 [==============================] - 31s 581ms/step - loss: 1.0416 - accuracy: 0.4987 - precision_1: 0.5238 - recall_1: 0.2544 - val_loss: 1.0314 - val_accuracy: 0.5012 - val_precision_1: 0.8333 - val_recall_1: 0.0120
# Epoch 57/60
# 53/53 [==============================] - 31s 590ms/step - loss: 1.0352 - accuracy: 0.4990 - precision_1: 0.5394 - recall_1: 0.2297 - val_loss: 1.0302 - val_accuracy: 0.5018 - val_precision_1: 0.5581 - val_recall_1: 0.4129
# Epoch 58/60
# 53/53 [==============================] - 31s 589ms/step - loss: 1.0378 - accuracy: 0.4984 - precision_1: 0.5196 - recall_1: 0.2247 - val_loss: 1.0328 - val_accuracy: 0.5000 - val_precision_1: 0.5130 - val_recall_1: 0.4880
# Epoch 59/60
# 53/53 [==============================] - 31s 589ms/step - loss: 1.0391 - accuracy: 0.5016 - precision_1: 0.5428 - recall_1: 0.2541 - val_loss: 1.0301 - val_accuracy: 0.4994 - val_precision_1: 0.5202 - val_recall_1: 0.4790
# Epoch 60/60
# 53/53 [==============================] - 31s 590ms/step - loss: 1.0373 - accuracy: 0.4999 - precision_1: 0.5237 - recall_1: 0.2660 - val_loss: 1.0301 - val_accuracy: 0.5000 - val_precision_1: 0.5078 - val_recall_1: 0.4916

# %%
# store accuracy, loss, precision, and recall values
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

prec = history.history['precision_1']
val_prec = history.history['val_precision_1']

recall = history.history['recall_1']
val_recall = history.history['val_recall_1']

epochs_range = range(60)

# %%
# plot training and validation accuracy
plt.figure(figsize=(12, 8))
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend();

# %%
# plot training and validation loss
plt.figure(figsize=(12, 8))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend();

# %%
# plot training and validation precision
plt.figure(figsize=(12, 8))
plt.plot(epochs_range, prec, label='Training Precision')
plt.plot(epochs_range, val_prec, label='Validation Precision')
plt.title('Training and Validation Precision')
plt.legend();

# %%
# plot training and validation recall
plt.figure(figsize=(12, 8))
plt.plot(epochs_range, recall, label='Training Recall')
plt.plot(epochs_range, val_recall, label='Validation Recall')
plt.title('Training and Validation Recall')
plt.legend();

# %% [markdown]
# Based on the charts this model stops improving after about 17 or so epochs. This model's best accuracy, precision, and recall are all about 50%. This model performs the worst out of all models essentially doing as well as the baseline model.

# %%
# save best mobile net v3 model
model.save('/content/drive/MyDrive/project-5/mobilenetv3-model.h5')
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

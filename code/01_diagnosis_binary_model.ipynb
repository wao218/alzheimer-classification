# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 5: Alzheimer's Image Classification
#
# ---
# ## Problem Statement
#
# You are a data science team that has been tasked by the UK government to develop a diagnostic solution that can improve the prediction rates of dementia and Alzheimer's within UK hospitals.  Using a Convolutional Neural Network on brain scan imaging, our group wishes to predict Alzheimer's disease with at least 50% accuracy and a recall of at least 64%. This metric is benchmarked to the average diagnostic performance of hospitals across the UK for patients, and an improvement in detection here can mean better outcomes and care for those within its early stages.
#
# ---

# %%
import glob
import imageio
import numpy as np
import pandas as pd 
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from tensorflow.keras.metrics import Precision
from tensorflow.keras.models import Sequential
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

# %%
#Read in files
directories=glob.glob("../data/train/*")
folders=[]
for folder in directories:
    folder=glob.glob(folder+'/*.jpg')
    folders.append(folder)

#Creating datasets
x=[]
y=[]
for folder in folders:
    rem=len(folder)
    for file in folder:
        image=imageio.imread(file).astype('float32')
        image=(pd.DataFrame(image)/255).values
        image=np.array(image)
        x.append(image)
        if '../data/train/NonDemented' in file:
            y.append(0)
        else:
             y.append(1)

#Formating data
x=np.array(x)
for i in x:
    i=i.reshape(i.shape[0],i.shape[1],1)
y_temp=np.array(y)

X_train, X_test, y_train, y_test = train_test_split(x, y_temp,stratify=y,random_state=42)

# %%
from tensorflow.keras.layers import Dropout
model= Sequential()

model.add(Flatten(input_shape=(208,176,1)))
model.add(Dropout(0.10))
model.add(Dense(8000, activation='relu'))
model.add(Dropout(0.10))
model.add(Dense(1, activation='sigmoid'))
          
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy',Precision()])

# %%
early_stop = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)
history = model.fit(X_train,
                    y_train, 
                    validation_data=(X_test, y_test),
                    epochs=25,
                    callbacks=[early_stop])
# Out:
# Epoch 1/25
# 120/120 [==============================] - 512s 4s/step - loss: 5.5319 - accuracy: 0.5878 - precision: 0.5896 - val_loss: 0.5263 - val_accuracy: 0.7494 - val_precision: 0.6937
# Epoch 2/25
# 120/120 [==============================] - 363s 3s/step - loss: 0.6860 - accuracy: 0.6875 - precision: 0.6875 - val_loss: 0.4567 - val_accuracy: 0.7736 - val_precision: 0.7224
# Epoch 3/25
# 120/120 [==============================] - 355s 3s/step - loss: 0.5560 - accuracy: 0.7216 - precision: 0.7190 - val_loss: 0.4665 - val_accuracy: 0.7611 - val_precision: 0.8618
# Epoch 4/25
# 120/120 [==============================] - 360s 3s/step - loss: 0.5079 - accuracy: 0.7430 - precision: 0.7391 - val_loss: 0.6076 - val_accuracy: 0.6628 - val_precision: 0.9860
# Epoch 5/25
# 120/120 [==============================] - 307s 2s/step - loss: 0.4588 - accuracy: 0.7750 - precision: 0.7739 - val_loss: 0.3950 - val_accuracy: 0.8322 - val_precision: 0.7902
# Epoch 6/25
# 120/120 [==============================] - 245s 2s/step - loss: 0.4190 - accuracy: 0.8023 - precision: 0.8022 - val_loss: 0.7039 - val_accuracy: 0.6362 - val_precision: 0.5790
# Epoch 7/25
# 120/120 [==============================] - 247s 2s/step - loss: 0.4557 - accuracy: 0.7917 - precision: 0.7954 - val_loss: 0.5002 - val_accuracy: 0.7330 - val_precision: 0.6540
# Epoch 8/25
# 120/120 [==============================] - 250s 2s/step - loss: 0.4698 - accuracy: 0.7633 - precision: 0.7618 - val_loss: 0.4724 - val_accuracy: 0.7580 - val_precision: 0.9688
# Epoch 9/25
# 120/120 [==============================] - 330s 3s/step - loss: 0.4122 - accuracy: 0.8044 - precision: 0.8055 - val_loss: 0.3852 - val_accuracy: 0.8119 - val_precision: 0.7481
# Epoch 10/25
# 120/120 [==============================] - 386s 3s/step - loss: 0.4179 - accuracy: 0.8042 - precision: 0.8048 - val_loss: 0.3435 - val_accuracy: 0.8579 - val_precision: 0.8626
# Epoch 11/25
# 120/120 [==============================] - 313s 3s/step - loss: 0.3461 - accuracy: 0.8435 - precision: 0.8422 - val_loss: 0.4460 - val_accuracy: 0.7752 - val_precision: 0.9836
# Epoch 12/25
# 120/120 [==============================] - 320s 3s/step - loss: 0.3689 - accuracy: 0.8349 - precision: 0.8359 - val_loss: 0.5751 - val_accuracy: 0.6674 - val_precision: 0.6007
# Epoch 13/25
# 120/120 [==============================] - 325s 3s/step - loss: 0.3697 - accuracy: 0.8320 - precision: 0.8375 - val_loss: 0.3077 - val_accuracy: 0.8657 - val_precision: 0.8423
# Epoch 14/25
# 120/120 [==============================] - 366s 3s/step - loss: 0.3790 - accuracy: 0.8227 - precision: 0.8228 - val_loss: 0.3995 - val_accuracy: 0.7955 - val_precision: 0.7161
# Epoch 15/25
# 120/120 [==============================] - 304s 2s/step - loss: 0.3144 - accuracy: 0.8638 - precision: 0.8625 - val_loss: 0.3027 - val_accuracy: 0.8712 - val_precision: 0.8333
# Epoch 16/25
# 120/120 [==============================] - 302s 2s/step - loss: 0.4140 - accuracy: 0.8060 - precision: 0.8065 - val_loss: 0.3237 - val_accuracy: 0.8728 - val_precision: 0.9314
# Epoch 17/25
# 120/120 [==============================] - 293s 2s/step - loss: 0.3499 - accuracy: 0.8383 - precision: 0.8374 - val_loss: 0.3002 - val_accuracy: 0.8751 - val_precision: 0.8672
# Epoch 18/25
# 120/120 [==============================] - 549s 5s/step - loss: 0.3071 - accuracy: 0.8669 - precision: 0.8652 - val_loss: 0.2945 - val_accuracy: 0.8689 - val_precision: 0.8174
# Epoch 19/25
# 120/120 [==============================] - 356s 3s/step - loss: 0.2955 - accuracy: 0.8703 - precision: 0.8676 - val_loss: 0.5853 - val_accuracy: 0.7026 - val_precision: 1.0000
# Epoch 20/25
# 120/120 [==============================] - 323s 3s/step - loss: 0.3371 - accuracy: 0.8466 - precision: 0.8497 - val_loss: 0.2657 - val_accuracy: 0.9001 - val_precision: 0.9296
# Epoch 21/25
# 120/120 [==============================] - 274s 2s/step - loss: 0.2807 - accuracy: 0.8773 - precision: 0.8760 - val_loss: 0.3404 - val_accuracy: 0.8236 - val_precision: 0.7497
# Epoch 22/25
# 120/120 [==============================] - 321s 3s/step - loss: 0.2446 - accuracy: 0.9000 - precision: 0.9034 - val_loss: 0.3102 - val_accuracy: 0.8431 - val_precision: 0.7743
# Epoch 23/25
# 120/120 [==============================] - 310s 3s/step - loss: 0.2789 - accuracy: 0.8846 - precision: 0.8852 - val_loss: 0.4125 - val_accuracy: 0.7838 - val_precision: 0.7036
# Epoch 24/25
# 120/120 [==============================] - 271s 2s/step - loss: 0.3409 - accuracy: 0.8440 - precision: 0.8478 - val_loss: 0.2780 - val_accuracy: 0.8907 - val_precision: 0.8848
# Epoch 25/25
# 120/120 [==============================] - 266s 2s/step - loss: 0.2850 - accuracy: 0.8789 - precision: 0.8787 - val_loss: 0.2734 - val_accuracy: 0.8743 - val_precision: 0.8261

# %%
# Test metrics over epochs.
train_acc = history.history['accuracy']
train_pre = history.history[f'precision']
test_acc = history.history[f'val_accuracy']
test_pre = history.history[f'val_precision']

epoch_labels = history.epoch

# Set figure size.
plt.figure(figsize=(12, 8))

# Generate line plot of training, testing loss over epochs.
plt.plot(train_acc, label='Training Accuracy', color='blue',linewidth=5)
plt.plot(train_pre, label='Training Precision', color='lightblue',linewidth=5)
plt.plot(test_acc, label='Testing Accuracy', color='red',linewidth=5)
plt.plot(test_pre, label='Testing Precision', color='orange',linewidth=5)
plt.xlabel('Epoch')
plt.ylabel('Percentage')
plt.title('Test Metrics Over Epochs')
plt.legend(fontsize=18);

# %%
#Model Metrics
pred=[1 if i[0]>=.5 else 0 for i in model.predict(X_test)]
print(classification_report(y_test, pred, target_names=['0','1']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.80      0.86       640
#            1       0.83      0.95      0.88       641
#
#     accuracy                           0.87      1281
#    macro avg       0.88      0.87      0.87      1281
# weighted avg       0.88      0.87      0.87      1281

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 36608)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 36608)             0
# _________________________________________________________________
# dense (Dense)                (None, 8000)              292872000
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8000)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 8001
# =================================================================
# Total params: 292,880,001
# Trainable params: 292,880,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Creating a confustion matrix
temp=tf.math.confusion_matrix(y_test, pred)
sns.heatmap(temp, annot=True, fmt="d",cmap="YlGnBu")
# Out:
# <AxesSubplot:>
